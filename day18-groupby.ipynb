# %%
import pandas as pd

data = [
    ["Electronics", "Laptop", "North", 50000],
    ["Electronics", "Mobile", "South", 20000],
    ["Furniture", "Chair", "East", 3000],
    ["Furniture", "Table", "West", 7000],
    ["Clothing", "Shirt", "North", 1500],
    ["Clothing", "Jeans", "South", 2500],
    ["Electronics", "Tablet", "East", 15000],
    ["Furniture", "Sofa", "West", 20000],
    ["Clothing", "Jacket", "North", 3500],
    ["Electronics", "Laptop", "South", 52000],
    ["Electronics", "Mobile", "East", 22000],
    ["Furniture", "Chair", "West", 3200],
    ["Furniture", "Table", "North", 7500],
    ["Clothing", "Shirt", "South", 1800],
    ["Clothing", "Jeans", "East", 2700],
    ["Electronics", "Tablet", "West", 16000],
    ["Furniture", "Sofa", "North", 21000],
    ["Clothing", "Jacket", "South", 3700],
    ["Electronics", "Laptop", "East", 51000],
    ["Electronics", "Mobile", "West", 21000],
    ["Furniture", "Chair", "North", 3100],
    ["Furniture", "Table", "South", 7200],
    ["Clothing", "Shirt", "East", 1600],
    ["Clothing", "Jeans", "West", 2600],
    ["Electronics", "Tablet", "North", 15500],
    ["Furniture", "Sofa", "South", 20500],
    ["Clothing", "Jacket", "East", 3600],
    ["Electronics", "Laptop", "West", 53000],
    ["Electronics", "Mobile", "North", 23000],
    ["Furniture", "Chair", "South", 3300],
    ["Furniture", "Table", "East", 7400],
    ["Clothing", "Shirt", "West", 1700],
    ["Clothing", "Jeans", "North", 2800],
    ["Electronics", "Tablet", "South", 15800],
    ["Furniture", "Sofa", "East", 21500],
    ["Clothing", "Jacket", "West", 3800],
    ["Electronics", "Laptop", "North", 54000],
    ["Electronics", "Mobile", "South", 24000],
    ["Furniture", "Chair", "East", 3400],
    ["Furniture", "Table", "West", 7600],
    ["Clothing", "Shirt", "North", 1900],
    ["Clothing", "Jeans", "South", 2900],
    ["Electronics", "Tablet", "East", 16200],
    ["Furniture", "Sofa", "West", 22000],
    ["Clothing", "Jacket", "North", 3900],
    ["Electronics", "Laptop", "South", 55000],
    ["Electronics", "Mobile", "East", 25000],
    ["Furniture", "Chair", "West", 3500],
    ["Furniture", "Table", "North", 7800],
    ["Clothing", "Shirt", "South", 2000]
]

df = pd.DataFrame(data, columns=["Category", "Product", "Region", "Sales"])

df.head()
# Out:
#       Category Product Region  Sales
# 0  Electronics  Laptop  North  50000
# 1  Electronics  Mobile  South  20000
# 2    Furniture   Chair   East   3000
# 3    Furniture   Table   West   7000
# 4     Clothing   Shirt  North   1500

# %%
df.groupby("Category")["Sales"].sum()
# Out:
# Category
# Clothing        42500
# Electronics    528500
# Furniture      169000
# Name: Sales, dtype: int64

# %%
df.groupby("Category")["Sales"].mean()
# Out:
# Category
# Clothing        2656.250000
# Electronics    31088.235294
# Furniture       9941.176471
# Name: Sales, dtype: float64

# %%
df["Category"].value_counts()
# Out:
# Category
# Electronics    17
# Furniture      17
# Clothing       16
# Name: count, dtype: int64

# %% [markdown]
# ### Comparison with Power BI
#
# I used Pandas groupby() to calculate total, average, and count for each category.
#
# The results matched the Power BI bar chart values.
#
# This shows that both Pandas and Power BI use the same aggregation logic.
#
# If there were small differences, it could be due to:
# - Missing values handled differently
# - Filters applied in Power BI
# - Data cleaning differences
