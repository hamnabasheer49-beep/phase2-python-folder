# %%
#This notebook stores my personal details and calculates my age in different units.

# %%
name="Hamna"
age=20
city="Kochi"

# %%
months=age*12
days=age*365
hours=days*24

# %%
print("My name is:",name)
print("I live in:",city)
print("My age in month is:",months)
print("My age in days is:",days)
print("My age in hours is:",hours)
# Out:
# My name is: Hamna
# I live in: Kochi
# My age in month is: 240
# My age in days is: 7300
# My age in hours is: 175200

# %%
print("Hello)
# Out:
#   Cell In[5], line 1
#     print("Hello)
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
# This error means I forgot to close the quotation mark in the print statement.
