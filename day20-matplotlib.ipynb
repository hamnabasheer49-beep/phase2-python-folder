# %%
import pandas as pd
import matplotlib.pyplot as plt

data = [
[1001,"2024-01-01","Electronics","Phone","South",15000,2],
[1002,"2024-01-02","Clothing","T-Shirt","North",800,5],
[1003,"2024-01-03","Electronics","Laptop","West",55000,1],
[1004,"2024-01-04","Furniture","Chair","East",3000,4],
[1005,"2024-01-05","Clothing","Jeans","South",2000,2],
[1006,"2024-01-06","Electronics","Tablet","North",12000,3],
[1007,"2024-01-07","Furniture","Table","West",7000,1],
[1008,"2024-01-08","Clothing","Jacket","East",3500,2],
[1009,"2024-01-09","Electronics","Phone","South",18000,2],
[1010,"2024-01-10","Furniture","Sofa","North",25000,1],
[1011,"2024-01-11","Clothing","T-Shirt","West",900,6],
[1012,"2024-01-12","Electronics","Laptop","East",60000,1],
[1013,"2024-01-13","Furniture","Chair","South",3200,3],
[1014,"2024-01-14","Clothing","Jeans","North",2100,2],
[1015,"2024-01-15","Electronics","Tablet","West",13000,2],
[1016,"2024-01-16","Furniture","Table","East",7500,1],
[1017,"2024-01-17","Clothing","Jacket","South",3700,2],
[1018,"2024-01-18","Electronics","Phone","North",16000,2],
[1019,"2024-01-19","Furniture","Sofa","West",26000,1],
[1020,"2024-01-20","Clothing","T-Shirt","East",850,4],
[1021,"2024-01-21","Electronics","Laptop","South",58000,1],
[1022,"2024-01-22","Furniture","Chair","North",3100,2],
[1023,"2024-01-23","Clothing","Jeans","West",2200,3],
[1024,"2024-01-24","Electronics","Tablet","East",14000,2],
[1025,"2024-01-25","Furniture","Table","South",7200,1],
[1026,"2024-01-26","Clothing","Jacket","North",3900,2],
[1027,"2024-01-27","Electronics","Phone","West",17000,2],
[1028,"2024-01-28","Furniture","Sofa","East",24000,1],
[1029,"2024-01-29","Clothing","T-Shirt","South",950,5],
[1030,"2024-01-30","Electronics","Laptop","North",62000,1],
[1031,"2024-01-31","Furniture","Chair","West",3300,3],
[1032,"2024-02-01","Clothing","Jeans","East",2300,2],
[1033,"2024-02-02","Electronics","Tablet","South",12500,2],
[1034,"2024-02-03","Furniture","Table","North",7600,1],
[1035,"2024-02-04","Clothing","Jacket","West",3600,2],
[1036,"2024-02-05","Electronics","Phone","East",15500,2],
[1037,"2024-02-06","Furniture","Sofa","South",25500,1],
[1038,"2024-02-07","Clothing","T-Shirt","North",880,4],
[1039,"2024-02-08","Electronics","Laptop","West",59000,1],
[1040,"2024-02-09","Furniture","Chair","East",3400,3],
[1041,"2024-02-10","Clothing","Jeans","South",2400,2],
[1042,"2024-02-11","Electronics","Tablet","North",13500,2],
[1043,"2024-02-12","Furniture","Table","West",7800,1],
[1044,"2024-02-13","Clothing","Jacket","East",3800,2],
[1045,"2024-02-14","Electronics","Phone","South",16500,2],
[1046,"2024-02-15","Furniture","Sofa","North",27000,1],
[1047,"2024-02-16","Clothing","T-Shirt","West",920,5],
[1048,"2024-02-17","Electronics","Laptop","East",61000,1],
[1049,"2024-02-18","Furniture","Chair","South",3500,3],
[1050,"2024-02-19","Clothing","Jeans","North",2500,2]
]

columns = ["OrderID","Date","Category","Product","Region","Sales","Quantity"]

df = pd.DataFrame(data, columns=columns)

df.head()
# Out:
#    OrderID        Date     Category  Product Region  Sales  Quantity
# 0     1001  2024-01-01  Electronics    Phone  South  15000         2
# 1     1002  2024-01-02     Clothing  T-Shirt  North    800         5
# 2     1003  2024-01-03  Electronics   Laptop   West  55000         1
# 3     1004  2024-01-04    Furniture    Chair   East   3000         4
# 4     1005  2024-01-05     Clothing    Jeans  South   2000         2

# %%
category_sales=df.groupby("Category")["Sales"].sum()
plt.figure(figsize=(8,4))
plt.bar(category_sales.index,category_sales.values,color="skyblue")
plt.title("Total sales by category")
plt.xlabel("Category")
plt.ylabel(" Total Sales")
plt.show()

# %% [markdown]
# # This chart shows the total sales for each category, helping compare performance across categories.

# %%
plt.figure(figsize=(8,4))
plt.plot(df["Date"],df["Sales"],color="orange")
plt.title("Sales Trend by Date")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.show()

# %% [markdown]
# # This chart shows how sales values change across different Dates.

# %%
plt.figure(figsize=(8,4))
plt.hist(df["Sales"],color="red")
plt.title("Sales distribution")
plt.xlabel("Sales")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# # This chart shows the distribution of sales values, indicating how frequently different sales amounts occur.

# %%
category_sales = df.groupby('Category')['Sales'].sum()

plt.figure(figsize=(8,4))
plt.bar(category_sales.index, category_sales.values, color='orange')

plt.title("Sales by Category (Recreated from Power BI)")
plt.xlabel("Category")
plt.ylabel("Total Sales")

plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# ### This chart recreates the Power BI bar chart using Matplotlib. Both charts show total sales by category and produce the same values, but Power BI uses drag-and-drop while Python requires manual coding.

# %% [markdown]
# ### Comparison:
# Power BI is easier and faster to create charts using drag-and-drop features.
# Matplotlib requires more effort and coding, but it provides greater flexibility and control over customization.
